# %% [markdown]
# # Jupyter 기본 Folder 위치 변경
# (*Anaconda 설치된 경우)

# %% [markdown]
# 1. Jupyter가 실행될 때, Path 정보를 읽도록 파일 형성
#
#    Anaconda Powershell Prompt에서 'jupyter notebook --generate-config' 입력
#    ![image.png](attachment:image.png)

# %% [markdown]
# 2. 아래와 같이 C 드라이버의 사용자 폴더에 있는 jupyter 폴더에 생성된 'jupyter_notebook_config.py' 파일을 찾음.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 메모장으로 열고 266번째 줄에 'c.NotebookApp.notebook_dir' 경로 정보를 찾음.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. 맨 앞의 주석 '#' 표시 삭제 및 원하는 폴더 경로로 수정
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. 시작 메뉴에서 아래와 같이, Jupyter 메뉴를 우클릭하고 파일 위치 열기
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. Jupyter 아이콘 우클릭하여 '속성'을 확인
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. 아래 표시한 %~~% 정보를 삭제 후 확인.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 8. Jupyter를 처음부터 다시 실행하면 아래와 같이 지정한 폴더에서 시작됨.
#
# ![image.png](attachment:image.png)
